# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
lambda_param = 0.1     
num_samples = 10000     

U = np.random.uniform(0, 1, num_samples)

X = -np.log(U) / lambda_param

plt.hist(X, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black')
plt.title("Exponential Random Variates using Inverse Transform")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

print("First 10 generated random variates:", X[:10])
# Out:
# First 10 generated random variates: [30.33293291  1.28584373  1.46270391 21.7328292   2.95231311  2.69749403
#   5.54646057  4.65329457  5.83159691  1.14102413]
